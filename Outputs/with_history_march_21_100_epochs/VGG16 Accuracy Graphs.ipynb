# %%
import sys
sys.path.append(".")
import numpy as np
import glob
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetB3
import matplotlib.pylab as plt
from pathlib import Path
from tensorflow.keras import layers
import datetime

# %%
VGG16_Scratch2Dense_history = np.load("VGG16_Scratch2Dense_history.npy",allow_pickle=True).item()
VGG16_Scratch52_history = np.load("VGG16_Scratch52_history.npy",allow_pickle=True).item()

# %%
print(VGG16_Scratch2Dense_history)
# Out:
# {'loss': [3.961519956588745, 3.951408863067627, 3.951417922973633, 3.9515295028686523, 3.9516680240631104, 3.951472759246826, 3.951427459716797, 3.9514658451080322, 3.9514966011047363, 3.9515838623046875, 3.95143461227417, 3.951427936553955, 3.951382637023926, 3.9514319896698, 3.951417922973633, 3.951340913772583], 'dense_loss': [1.3908965587615967, 1.386091947555542, 1.386190414428711, 1.386186122894287, 1.3862403631210327, 1.3861826658248901, 1.3861188888549805, 1.3861680030822754, 1.3861899375915527, 1.3861969709396362, 1.3862146139144897, 1.3861724138259888, 1.3861794471740723, 1.3861874341964722, 1.3861113786697388, 1.386060357093811], 'dense_1_loss': [2.570622682571411, 2.5653178691864014, 2.565228223800659, 2.565340995788574, 2.5654263496398926, 2.5652921199798584, 2.5653152465820312, 2.565295457839966, 2.5653040409088135, 2.565384864807129, 2.565218925476074, 2.5652554035186768, 2.565204620361328, 2.5652456283569336, 2.565305709838867, 2.565282106399536], 'dense_accuracy': [0
# ...

# %%
print(VGG16_Scratch2Dense_history['dense_1_accuracy'])
# Out:
# [0.0768275111913681, 0.07558512687683105, 0.07646681368350983, 0.0754648894071579, 0.07911189645528793, 0.07590574026107788, 0.07482366263866425, 0.07786951214075089, 0.0786309689283371, 0.0755450502038002, 0.0773485079407692, 0.0754648894071579, 0.07815004885196686, 0.07718820124864578, 0.07646681368350983, 0.07710804790258408]

# %%
# summarize history for VGG16_Scratch2Dense accuracy
plt.plot(VGG16_Scratch2Dense_history['dense_1_accuracy'])
plt.plot(VGG16_Scratch2Dense_history['val_dense_1_accuracy'])
plt.title('VGG16_Scratch2Dense  model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
print(VGG16_Scratch52_history)
# Out:
# {'loss': [5.264171123504639, 3.9510650634765625, 3.9509241580963135, 3.950948715209961, 3.9509260654449463, 3.9509079456329346, 3.9509191513061523, 3.950888156890869, 3.9509103298187256, 3.9508628845214844, 3.950873851776123, 3.9509098529815674, 3.950914144515991], 'accuracy': [0.019878165796399117, 0.021361013874411583, 0.020238857716321945, 0.021160628646612167, 0.0203190129250288, 0.021240781992673874, 0.018715934827923775, 0.020639628171920776, 0.01979801245033741, 0.020599551498889923, 0.02132093533873558, 0.020599551498889923, 0.020719781517982483], 'val_loss': [3.950496196746826, 3.950225830078125, 3.950178623199463, 3.9501631259918213, 3.9501607418060303, 3.9501566886901855, 3.95015025138855, 3.9501688480377197, 3.950155019760132, 3.9501638412475586, 3.950162887573242, 3.9501538276672363, 3.9501562118530273], 'val_accuracy': [0.02143087424337864, 0.02143087424337864, 0.02143087424337864, 0.021108604967594147, 0.02143087424337864, 0.021108604967594147, 0.02143087424337864, 0.0
# ...

# %%
# summarize history for accuracy
plt.plot(VGG16_Scratch52_history['accuracy'])
plt.plot(VGG16_Scratch52_history['val_accuracy'])
plt.title('VGG16_Scratch52_history model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
